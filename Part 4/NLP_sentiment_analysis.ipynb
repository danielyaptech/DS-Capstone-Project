# %% [markdown]
# # NLP Sentiment Analysis using TextBlob #

# %%
# Import all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
import string
import emoji
import contractions
import datatable as dt

from bs4 import BeautifulSoup
from langdetect import detect
from googletrans import Translator
from deep_translator import GoogleTranslator
from nltk.corpus import stopwords, wordnet, inaugural
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.probability import FreqDist
from wordcloud import WordCloud
from textblob import TextBlob
from textblob.classifiers import NaiveBayesClassifier
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
# Load and preview the dataset
df = pd.read_csv('Datasets/AirBnb_reviews.csv')
df.tail()
# Out:
#         listing_id            id       date  reviewer_id reviewer_name  \
# 342899  40606723.0  6.997740e+17  8/23/2022    199478251          Hugo
# 342900  40606723.0  6.998450e+17  8/23/2022    168768099         Cerys
# 342901  40606723.0  7.004880e+17  8/24/2022    118306945         Anita
# 342902  40606723.0  7.004940e+17  8/24/2022    403631092           Tos
# 342903  40606723.0  7.005040e+17  8/24/2022    467451204         Laura
#
#                                                  comments
# 342899                                Excelente ubicación
# 342900  Would definitely recommend. Perfect location, ...
# 342901  Hôtel bien situé, personnel d’accueil chaleure...
# 342902  Sehr freundliche Personal. Vom Hotel aus kann ...
# 342903  L’Hotel2Stay si trova in una posizione molto c...

# %% [markdown]
# ## EDA & Data Preprocessing ##

# %%
# Check the number of rows and columns of the dataset
df.shape
# Out:
# (342904, 6)

# %%
# Check for null values
df.isnull().sum()
# Out:
# listing_id        0
# id                0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         16
# dtype: int64

# %%
# Drop all the rows with null values
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# listing_id       0
# id               0
# date             0
# reviewer_id      0
# reviewer_name    0
# comments         0
# dtype: int64

# %%
# Check the number of rows after dropping the rows with null values
df.shape
# Out:
# (342888, 6)

# %%
# Remove the unnecessary columns and preview the dataset
df = df[['reviewer_name', 'comments']]

# Preview the trimmed dataset
df.head()
# Out:
#   reviewer_name                                           comments
# 0           Lam  Daniel is really cool. The place was nice and ...
# 1       Gregory  If you want the authentic Amsterdam houseboat ...
# 2       Michael  Unique and luxurious to be sure. I couldn't re...
# 3         Alice  Daniel is the most amazing host! His place is ...
# 4         Brian  My wife and I recently stopped in Amsterdam fo...

# %%
# Check for any non-text comment
df.sort_values(by='comments', ascending=False)
# Out:
#          reviewer_name                                           comments
# 276536           Faleh                                                  🧡
# 281739           Yuval                                                 🧠💍
# 327922              政揚                                                🦍🦍🦍
# 281629          Yamila                                                  🥰
# 300161       Sebastian                                                  🤡
# ...                ...                                                ...
# 61275   Thia (& Barry)  \r<br/>   I am reviewing a very unpleasant, un...
# 20715        Alexander  \r<br/>\r<br/>2. This apartment is an ideal ch...
# 68084             Mila  \r<br/>\r<br/>\r<br/>la biennvenida muy simpat...
# 51816           Judith  \r<br/>\r<br/>\r<br/>We stayed in Lot's flat f...
# 115308        Delphine  \r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<b...
#
# [342888 rows x 2 columns]

# %%
# Function to convert emojis to words
# def convert_emojis_to_words(text):
#     converted_text = emoji.demojize(text)
#     return converted_text


def convert_emoji(text, emoji_dict=None):
  """
  Converts emojis in text to corresponding words from the dictionary.

  Returns:
      String with emojis replaced by words or empty string.
  """

  # Import emoji library within the function
  import emoji

  if emoji_dict:
    # Replace emojis with words from the dictionary
    for emoji, word in emoji_dict.items():
      text = text.replace(emoji, word)
  else:
    # Remove emojis completely (default behavior of demojize)
    text = emoji.demojize(text)
  return text

# Apply the function to the 'comments' column and insert the converted emojis into a new column 'comments_cleaned'
df['comments_cleaned'] = df['comments'].apply(convert_emoji)

# Apply the function to the 'reviewer_name' column and insert the converted emojis into a new column 'reviewer_name_cleaned'
df['reviewer_name_cleaned'] = df['reviewer_name'].apply(convert_emoji)

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#          reviewer_name                                           comments  \
# 162594          Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848          Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722              齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061              響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638           Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                ...                                                ...
# 61275   Thia (& Barry)  \r<br/>   I am reviewing a very unpleasant, un...
# 20715        Alexander  \r<br/>\r<br/>2. This apartment is an ideal ch...
# 68084             Mila  \r<br/>\r<br/>\r<br/>la biennvenida muy simpat...
# 51816           Judith  \r<br/>\r<br/>\r<br/>We stayed in Lot's flat f...
# 115308        Delphine  \r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<b...
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                                                   ...
# 61275   \r<br/>   I am reviewing a very unpleasant, un...
# 20715   \r<br/>\r<br/>2. This apartment is an ideal ch...
# 68084   \r<br/>\r<br/>\r<br/>la biennvenida muy simpat...
# 51816   \r<br/>\r<br/>\r<br/>We stayed in Lot's flat f...
# 115308  \r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<b...
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 61275         Thia (& Barry)
# 20715              Alexander
# 68084                   Mila
# 51816                 Judith
# 115308              Delphine
#
# [342888 rows x 4 columns]

# %%
# Removing URLs
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: re.sub(r'http\S+|www.\S+', '', x))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: re.sub(r'http\S+|www.\S+', '', x))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#          reviewer_name                                           comments  \
# 162594          Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848          Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722              齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061              響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638           Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                ...                                                ...
# 61275   Thia (& Barry)  \r<br/>   I am reviewing a very unpleasant, un...
# 20715        Alexander  \r<br/>\r<br/>2. This apartment is an ideal ch...
# 68084             Mila  \r<br/>\r<br/>\r<br/>la biennvenida muy simpat...
# 51816           Judith  \r<br/>\r<br/>\r<br/>We stayed in Lot's flat f...
# 115308        Delphine  \r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<b...
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                                                   ...
# 61275   \r<br/>   I am reviewing a very unpleasant, un...
# 20715   \r<br/>\r<br/>2. This apartment is an ideal ch...
# 68084   \r<br/>\r<br/>\r<br/>la biennvenida muy simpat...
# 51816   \r<br/>\r<br/>\r<br/>We stayed in Lot's flat f...
# 115308  \r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<b...
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 61275         Thia (& Barry)
# 20715              Alexander
# 68084                   Mila
# 51816                 Judith
# 115308              Delphine
#
# [342888 rows x 4 columns]

# %%
# Removing HTML tags
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: BeautifulSoup(x, "lxml").text)
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: BeautifulSoup(x, "lxml").text)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_3432\3813491045.py:2: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: BeautifulSoup(x, "lxml").text)
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_3432\3813491045.py:3: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: BeautifulSoup(x, "lxml").text)

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#          reviewer_name                                           comments  \
# 162594          Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848          Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722              齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061              響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638           Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                ...                                                ...
# 51816           Judith  \r<br/>\r<br/>\r<br/>We stayed in Lot's flat f...
# 47219             Loïc   \r<br/>\r<br/>\r<br/>\r<br/>Very nice trip in...
# 61275   Thia (& Barry)  \r<br/>   I am reviewing a very unpleasant, un...
# 115308        Delphine  \r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<br/>\r<b...
# 109355          Helena                                                  <
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。日本人は朝食をしっかり食べますよね。B&Bなら朝食がついているかと思...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。年配者や酔っ払...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638  ﾎｽﾄはとても親切でｽﾃｷな笑顔の持ち主です返信も早いですお部屋もとても清潔で冬はとても暖か...
# ...                                                   ...
# 51816     We stayed in Lot's flat for 6 days and enjoy...
# 47219      Very nice trip in Amsterdam! Thanks to Eva'...
# 61275      I am reviewing a very unpleasant, unprofess...
# 115308                             Apartment very nice...
# 109355
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 51816                 Judith
# 47219                   Loïc
# 61275         Thia (& Barry)
# 115308              Delphine
# 109355                Helena
#
# [342888 rows x 4 columns]

# %%
# Removing punctuation
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#        reviewer_name                                           comments  \
# 162594        Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848        Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722            齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061            響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638         Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...              ...                                                ...
# 321175    Antoinette                                                  -
# 317249    Luca Carlo                                                  .
# 285272          Iris                                                  .
# 22170          Derek                                                  .
# 251636         Simon                                                 :)
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。日本人は朝食をしっかり食べますよね。BBなら朝食がついているかと思っ...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。年配者や酔っ払...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638  ﾎｽﾄはとても親切でｽﾃｷな笑顔の持ち主です返信も早いですお部屋もとても清潔で冬はとても暖か...
# ...                                                   ...
# 321175
# 317249
# 285272
# 22170
# 251636
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 321175            Antoinette
# 317249            Luca Carlo
# 285272                  Iris
# 22170                  Derek
# 251636                 Simon
#
# [342888 rows x 4 columns]

# %%
# Removing numbers
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: re.sub(r'\d+', '', x))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: re.sub(r'\d+', '', x))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#        reviewer_name                                           comments  \
# 162594        Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848        Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722            齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061            響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638         Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...              ...                                                ...
# 310928        Thomas                                                  .
# 62031           Jodi                                                  .
# 335196           فهد                                                  .
# 318868         Hauke                                                  ?
# 151181           Gem                                                 :)
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。日本人は朝食をしっかり食べますよね。BBなら朝食がついているかと思っ...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。年配者や酔っ払...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあり...
# 187638  ﾎｽﾄはとても親切でｽﾃｷな笑顔の持ち主です返信も早いですお部屋もとても清潔で冬はとても暖か...
# ...                                                   ...
# 310928
# 62031
# 335196
# 318868
# 151181
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 310928                Thomas
# 62031                   Jodi
# 335196                   فهد
# 318868                 Hauke
# 151181                   Gem
#
# [342888 rows x 4 columns]

# %%
# Removing extra spaces
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: ' '.join(x.split()))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: ' '.join(x.split()))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#             reviewer_name                                           comments  \
# 162594             Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848             Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722                 齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061                 響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638              Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                   ...                                                ...
# 197484  Marc And Angelica                                                 ..
# 208708                Cem                                                  .
# 293663               Javo                                                  .
# 291342           Riccardo                                                  .
# 199603                Tal                                                  1
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。日本人は朝食をしっかり食べますよね。BBなら朝食がついているかと思っ...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。年配者や酔っ払...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあり...
# 187638  ﾎｽﾄはとても親切でｽﾃｷな笑顔の持ち主です返信も早いですお部屋もとても清潔で冬はとても暖か...
# ...                                                   ...
# 197484
# 208708
# 293663
# 291342
# 199603
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 197484     Marc And Angelica
# 208708                   Cem
# 293663                  Javo
# 291342              Riccardo
# 199603                   Tal
#
# [342888 rows x 4 columns]

# %%
# Replacing repetitions of punctuation
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: re.sub(r'(\W)\1+', r'\1', x))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: re.sub(r'(\W)\1+', r'\1', x))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#             reviewer_name                                           comments  \
# 162594             Hitomi  ﾛｹｰｼｮﾝは最高です。<br/>日本人は朝食をしっかり食べますよね。B&Bなら朝食がついて...
# 237848             Yutaka  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。<br/>年配...
# 276722                 齊藤  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061                 響子  ﾎｽﾄはとても親切の方で2匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあ...
# 187638              Akiko  ﾎｽﾄはとても親切で<br/>ｽﾃｷな笑顔の持ち主です<br/><br/>返信も早いです<b...
# ...                   ...                                                ...
# 197484  Marc And Angelica                                                 ..
# 208708                Cem                                                  .
# 293663               Javo                                                  .
# 291342           Riccardo                                                  .
# 199603                Tal                                                  1
#
#                                          comments_cleaned  \
# 162594  ﾛｹｰｼｮﾝは最高です。日本人は朝食をしっかり食べますよね。BBなら朝食がついているかと思っ...
# 237848  ﾛｹｰｼｮﾝはよいですが､今まで見たことも無い様な狭くて急な階段がｶﾞﾝです。年配者や酔っ払...
# 276722  ﾎﾃﾙの前の公園が大きくて､散歩にちょうどいい。部屋は綺麗に掃除してあります。ﾌﾛﾝﾄ対応も...
# 226061  ﾎｽﾄはとても親切の方で匹の犬もとても可愛いです。場所もよく近くにはｽｰﾊﾟｰがたくさんあり...
# 187638  ﾎｽﾄはとても親切でｽﾃｷな笑顔の持ち主です返信も早いですお部屋もとても清潔で冬はとても暖か...
# ...                                                   ...
# 197484
# 208708
# 293663
# 291342
# 199603
#
#        reviewer_name_cleaned
# 162594                Hitomi
# 237848                Yutaka
# 276722                    齊藤
# 226061                    響子
# 187638                 Akiko
# ...                      ...
# 197484     Marc And Angelica
# 208708                   Cem
# 293663                  Javo
# 291342              Riccardo
# 199603                   Tal
#
# [342888 rows x 4 columns]

# %%
# Removing special characters
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: re.sub(r'[^a-zA-Z0-9\s]', '', x))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#                reviewer_name  \
# 19031                 Andrea
# 241718               Weidong
# 341079             Ezzeddine
# 319819             Christian
# 125376                 Paula
# ...                      ...
# 321004                  Rolf
# 265247  Charlotte Wilhelmina
# 230364                  מעין
# 276417                    成英
# 66584                 Stefan
#
#                                                  comments  \
# 19031   - zuverlässiger Gastgeber<br/>- alles vor Ort ...
# 241718  房间很宽敞，采光也很好，位于顶楼，周边交通便利，步行十几分钟就可到达地铁站，可乘坐52路前往...
# 341079  1000 %  zu empfehlen<br/>Für jung und alt, mit...
# 319819  zu empfehlen 30 minuten von Amsterdam<br/>mit ...
# 125376                                       zu empfehlen
# ...                                                   ...
# 321004                                                  -
# 265247                                                  .
# 230364                                                ...
# 276417  ここのﾎﾃﾙは予約変更が出来たと言ったのに､次の日になると予約変更出来てないと言われて無理や...
# 66584                                                   .
#
#                                          comments_cleaned  \
# 19031   zuverlssiger Gastgeber alles vor Ort wie in de...
# 241718                                     zuidtramKevin
# 341079  zu empfehlenFr jung und alt mit und ohne Kinde...
# 319819  zu empfehlen minuten von Amsterdammit der tram...
# 125376                                       zu empfehlen
# ...                                                   ...
# 321004
# 265247
# 230364
# 276417
# 66584
#
#        reviewer_name_cleaned
# 19031                 Andrea
# 241718               Weidong
# 341079             Ezzeddine
# 319819             Christian
# 125376                 Paula
# ...                      ...
# 321004                  Rolf
# 265247  Charlotte Wilhelmina
# 230364
# 276417
# 66584                 Stefan
#
# [342888 rows x 4 columns]

# %%
# Removing contractions
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: contractions.fix(x))
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: contractions.fix(x))

# %%
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#        reviewer_name                                           comments  \
# 19031         Andrea  - zuverlässiger Gastgeber<br/>- alles vor Ort ...
# 241718       Weidong  房间很宽敞，采光也很好，位于顶楼，周边交通便利，步行十几分钟就可到达地铁站，可乘坐52路前往...
# 341079     Ezzeddine  1000 %  zu empfehlen<br/>Für jung und alt, mit...
# 319819     Christian  zu empfehlen 30 minuten von Amsterdam<br/>mit ...
# 125376         Paula                                       zu empfehlen
# ...              ...                                                ...
# 233974        Sidsel                                                  .
# 262373         Marie                                                  -
# 226541          Jing  房子真的是一尘不染，比照片看上去还要好，还有免费停车，就是距离地铁站大概1公里稍微远了些~欧...
# 70301             佩萱                     超棒的房東<br/>很親切，東西不見還幫我們找<br/>推推
# 112356          Fang               房間､浴室和廁所都很乾淨，還有很棒的頂樓，地點也很靠近市中心，非常方便！
#
#                                          comments_cleaned  \
# 19031   zuverlssiger Gastgeber alles vor Ort wie in de...
# 241718                                     zuidtramKevin
# 341079  zu empfehlenFr jung und alt mit und ohne Kinde...
# 319819  zu empfehlen minuten von Amsterdammit der tram...
# 125376                                       zu empfehlen
# ...                                                   ...
# 233974
# 262373
# 226541
# 70301
# 112356
#
#        reviewer_name_cleaned
# 19031                 Andrea
# 241718               Weidong
# 341079             Ezzeddine
# 319819             Christian
# 125376                 Paula
# ...                      ...
# 233974                Sidsel
# 262373                 Marie
# 226541                  Jing
# 70301
# 112356                  Fang
#
# [342888 rows x 4 columns]

# %%
# Lowercase the data
df['comments_cleaned'] = df['comments_cleaned'].apply(lambda x: x.lower())
df['reviewer_name_cleaned'] = df['reviewer_name_cleaned'].apply(lambda x: x.lower())

# %%
# A glance at the dataset after come cleaning
df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#        reviewer_name                                           comments  \
# 338150         Lucas                                               Zxvc
# 212024          Mona  Zwei wunderbare helle, saubere Zimmer in super...
# 35678           Eric  Zwei unvergleichliche Tage voller wunderbarer ...
# 246996          Gerd  Zwei sehr schöne Doppelzimmer mit einer - bei ...
# 273050       Andreas  Zwei Schlafzimmer sind super und temperierbar....
# ...              ...                                                ...
# 45399              兰                                很好的位置，很周到的房东，很优惠的价格
# 247891        Melina                                                 :)
# 51683             田添  素敵なご家族でした。息子さんの絵も貼ってあり､ｱｯﾄﾎｰﾑな空間でした。程よく都会から離れて...
# 129191            晶晶                 房东老爷爷很热情，离市区还算方便，房间较小，有蚊子，建议放些驱蚊水。
# 265194         Honor                                                 :)
#
#                                          comments_cleaned  \
# 338150                                               zxvc
# 212024  zwei wunderbare helle saubere zimmer in super ...
# 35678   zwei unvergleichliche tage voller wunderbarer ...
# 246996  zwei sehr schne doppelzimmer mit einer bei sch...
# 273050  zwei schlafzimmer sind super und temperierbar ...
# ...                                                   ...
# 45399
# 247891
# 51683
# 129191
# 265194
#
#        reviewer_name_cleaned
# 338150                 lucas
# 212024                  mona
# 35678                   eric
# 246996                  gerd
# 273050               andreas
# ...                      ...
# 45399
# 247891                melina
# 51683
# 129191
# 265194                 honor
#
# [342888 rows x 4 columns]

# %% [markdown]
# ### non-English Text ###

# %% [markdown]
# The dataset consists of non-English names and comments. We have two methods to deal with them, either remove them or translate them.

# %% [markdown]
# #### a. Text Removal ####

# %%
# Remove non-English words in 'comments'
# ************************************************

# Iterate through each row
for index, row in df.iterrows():
    text = row['comments']
    try:
        lang = detect(text)
    except:
        lang = 'unknown'
    if lang != 'en':
        df.at[index, 'comments_cleaned'] = ''  # Replace non-English text with an empty string

# %%
# Remove non-English words in 'reviewer_name'
# *****************************************************

# Iterate through each row
for index, row in df.iterrows():
    text = row['reviewer_name']
    try:
        lang = detect(text)
    except:
        lang = 'unknown'
    if lang != 'en':
        df.at[index, 'reviewer_name_cleaned'] = ''  # Replace non-English name with an empty string

# %%
# Check for null values in the dataset after removing the non-English text
df.isnull().sum()
# Out:
# reviewer_name            0
# comments                 0
# comments_cleaned         0
# reviewer_name_cleaned    0
# dtype: int64

# %% [markdown]
# #### b. Text Translation ####

# %% [markdown]
# Text translation can be done on non-English words into English words with the following code. However, due to my PC hardware limitation (I don't even have a GPU on my laptop), performing translation is going to take around 7 hours for both of the dataset's columns, 'comments_cleaned' and 'reviewer_name_cleaned'. Hence, I just leave the code here and you are welcome to run the codes if you have a higher specs PC to perform this task.
#
# **NOTE**: disable (comment out) 'Text Removal' code above if you wish to use the translation method.

# %%
# # Define the columns containing the text to translate
# comments_en = df['comments_cleaned']
# reviewer_name_en = df['reviewer_name_cleaned']

# %%
# # Create a new column for translated text
# df["comments_en"] = None
# df["reviewer_name_en"] = None

# %%
# # Initialize the translator
# translator = Translator()

# %%
# # Function to translate text (handles potential errors)
# def translate_text(text):
#   try:
#     # Detect source language automatically
#     translation = translator.translate(text, dest="en")
#     return translation.text
#   except Exception:
#     # Handle translation errors (e.g., network issues)
#     return ""

# %%
# # Apply translation to each row of 'comments_cleaned' column using vectorized function (faster)
# df["comments_en"] = df['comments_cleaned'].apply(translate_text)

# %%
# # Apply translation to each row of 'reviewer_name_cleaned' column using vectorized function (faster)
# df["reviewer_name_en"] = df['reviewer_name_cleaned'].apply(translate_text)

# %% [markdown]
# ### Further Preprocessing ###

# %% [markdown]
# After cleaning the non-English text part, we now export the dataframe to a new .csv file. Then we further preprocess the data of the new dataset.

# %%
# Export the updated dataframe
df.to_csv('data.csv', index=False)

# Load the new dataset
clean_df = pd.read_csv('data.csv')

# Preview the new dataset
clean_df.sort_values(by='comments_cleaned', ascending=False)
# Out:
#        reviewer_name                                           comments  \
# 121657         Felix  Zora's place was amazing.  Very homey and Zora...
# 121778        Jeremy  Zora’s place was a great- in a cute neighborho...
# 121651     Magdalena  Zora's place is very homely, and full of light...
# 121756         Angie  Zora's place is clean, however the apartment i...
# 121597     Katherine  Zora's home was wonderful, and she was an even...
# ...              ...                                                ...
# 342875          Anna  Ottimo rapporto qualità-prezzo, l’hotel è a un...
# 342883          Hugo                                Excelente ubicación
# 342885         Anita  Hôtel bien situé, personnel d’accueil chaleure...
# 342886           Tos  Sehr freundliche Personal. Vom Hotel aus kann ...
# 342887         Laura  L’Hotel2Stay si trova in una posizione molto c...
#
#                                          comments_cleaned  \
# 121657  zoras place was amazing very homey and zora da...
# 121778  zoras place was a great in a cute neighborhood...
# 121651  zoras place is very homely and full of light i...
# 121756  zoras place is clean however the apartment is ...
# 121597  zoras home was wonderful and she was an even b...
# ...                                                   ...
# 342875                                                NaN
# 342883                                                NaN
# 342885                                                NaN
# 342886                                                NaN
# 342887                                                NaN
#
#        reviewer_name_cleaned
# 121657                   NaN
# 121778                   NaN
# 121651                   NaN
# 121756                   NaN
# 121597                   NaN
# ...                      ...
# 342875                   NaN
# 342883                   NaN
# 342885                   NaN
# 342886                   tos
# 342887                   NaN
#
# [342888 rows x 4 columns]

# %%
# Drop all null values in the new dataset
clean_df.dropna(inplace=True)
clean_df.head(20)
# Out:
#          reviewer_name                                           comments  \
# 4                Brian  My wife and I recently stopped in Amsterdam fo...
# 9              Sherwin  Daniel is highly recommended.  He provided all...
# 17     Kevin And Nicky  The Houseboat was truly fabulous. A great loca...
# 20            Mathilde  The location is perfect and the boat is perfec...
# 21       Josh & Winnie  We had a lovely time in Derks houseboat in Ams...
# 22               Emily  We had such a lovely warm and comfortable stay...
# 28             Jessica  Staying on the houseboat was one of the highli...
# 36            Matthias  Great place to stay and discover the city. Esp...
# 40         Christopher  Location and setting truly can't be beat. Had ...
# 77                Thad  Daan's Houseboat was a treat to stay on. Not o...
# 79               Chris  Daan was a great host - helpful and very frien...
# 82              Sinead  Myself and three friends stayed on Daan's boat...
# 84            Cristina  Thanks Daan for making us welcome! Staying in ...
# 87                 Amy  Daan and his wife were great hosts. The boat i...
# 91          Christophe  Derk let us have an environment where you will...
# 118              Colin  Staying at Daniel's apartment was great! My bo...
# 124            Chelsea  We had the most beautiful relaxing holiday sta...
# 125            Pearlie  Daan's houseboat is amazing - very spacious an...
# 144        Christopher  Derk's houseboat is fantastic and located on a...
# 148  Jake And Cristine  Derk was an excellent host and the boathouse w...
#
#                                       comments_cleaned reviewer_name_cleaned
# 4    my wife and i recently stopped in amsterdam fo...                 brian
# 9    daniel is highly recommended he provided all n...               sherwin
# 17   the houseboat was truly fabulous a great locat...       kevin and nicky
# 20   the location is perfect and the boat is perfec...              mathilde
# 21   we had a lovely time in derks houseboat in ams...           josh winnie
# 22   we had such a lovely warm and comfortable stay...                 emily
# 28   staying on the houseboat was one of the highli...               jessica
# 36   great place to stay and discover the city espe...              matthias
# 40   location and setting truly cannot be beat had ...           christopher
# 77   daans houseboat was a treat to stay on not onl...                  thad
# 79   daan was a great host helpful and very friendl...                 chris
# 82   myself and three friends stayed on daans boat ...                sinead
# 84   thanks daan for making us welcome staying in a...              cristina
# 87   daan and his wife were great hosts the boat is...                   amy
# 91   derk let us have an environment where you will...            christophe
# 118  staying at daniels apartment was great my boyf...                 colin
# 124  we had the most beautiful relaxing holiday sta...               chelsea
# 125  daans houseboat is amazing very spacious and c...               pearlie
# 144  derks houseboat is fantastic and located on a ...           christopher
# 148  derk was an excellent host and the boathouse w...     jake and cristine

# %%
# Check the dataframe size after removing null values
clean_df.shape
# Out:
# (28923, 4)

# %%
# Tokenization for 'comments_cleaned' and 'reviewer_name_cleaned' columns
clean_df['comments_tokens'] = clean_df['comments_cleaned'].apply(lambda x: word_tokenize(x))
clean_df['reviewer_name_tokens'] = clean_df['reviewer_name_cleaned'].apply(lambda x: word_tokenize(x))

# %%
# Removing stopwords in the 'comments_cleaned' and 'reviewer_name_cleaned' columns
stop_words = set(stopwords.words('english'))
clean_df['comments_tokens'] = clean_df['comments_tokens'].apply(lambda x: [word for word in x if word not in stop_words])
clean_df['reviewer_name_tokens'] = clean_df['reviewer_name_tokens'].apply(lambda x: [word for word in x if word not in stop_words])

# %%
# Print the updated 'tokens' columns
clean_df.tail()
# Out:
#        reviewer_name                                           comments  \
# 342819        Sophie  The staff were really nice and attentive. The ...
# 342837         Terry  This hotel was fantastic. Quality staff, rooms...
# 342853         Barry                    Great hotel, fantastic location
# 342870    Christofer                                Great place to stay
# 342876          Octa  Clean and modern rooms, friendly staff, easy a...
#
#                                          comments_cleaned  \
# 342819  the staff were really nice and attentive the s...
# 342837  this hotel was fantastic quality staff rooms a...
# 342853                     great hotel fantastic location
# 342870                                great place to stay
# 342876  clean and modern rooms friendly staff easy acc...
#
#        reviewer_name_cleaned  \
# 342819                sophie
# 342837                 terry
# 342853                 barry
# 342870            christofer
# 342876                  octa
#
#                                           comments_tokens reviewer_name_tokens
# 342819  [staff, really, nice, attentive, studio, perfe...             [sophie]
# 342837  [hotel, fantastic, quality, staff, rooms, amen...              [terry]
# 342853                [great, hotel, fantastic, location]              [barry]
# 342870                               [great, place, stay]         [christofer]
# 342876  [clean, modern, rooms, friendly, staff, easy, ...               [octa]

# %% [markdown]
# #### Lemmatizing ####

# %%
# Initialize WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
# Part-of-Speech (POS) Tagging mapping dictionary
wordnet_map = {"N": wordnet.NOUN, "V": wordnet.VERB, "J": wordnet.ADJ, "R": wordnet.ADV}

# %%
# Function to perform Lemmatization on a text
def lemmatize_text(text):
    # Get the POS tags for the words
    pos_tags = nltk.pos_tag(text)
    
    # Perform Lemmatization
    lemmatized_words = []
    for word, tag in pos_tags:
        # Map the POS tag to WordNet POS tag
        pos = wordnet_map.get(tag[0].upper(), wordnet.NOUN)
        
        # Lemmatize the word with the appropriate POS tag
        lemmatized_word = lemmatizer.lemmatize(word, pos=pos)
        
        # Add the lemmatized word to the list
        lemmatized_words.append(lemmatized_word)
    
    return lemmatized_words

# %%
# Apply Lemmatization to the 'comments_tokens' column
clean_df['comments_tokens'] = clean_df['comments_tokens'].apply(lemmatize_text)

# %%
# Create a list of all tokens in 'comments_tokens'
all_comments_tokens = [token for tokens_list in clean_df['comments_tokens'] for token in tokens_list]

# %%
# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(nltk.FreqDist(all_comments_tokens)))

# %%
# Plot the word cloud
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# From the word cloud we can conclude that, the bigger the size of the word, the more frequent the word appears in the data. The following graph illustrates the word counts.

# %%
# Calculate word appearance frequency
freq_dist = FreqDist(all_comments_tokens)

# %%
# Plot the most common words
plt.figure(figsize=(7, 5))
freq_dist.plot(30, cumulative=False)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## Sentiment Analysis Modelling ##

# %%
clean_df.head()
# Out:
#       reviewer_name                                           comments  \
# 4             Brian  My wife and I recently stopped in Amsterdam fo...
# 9           Sherwin  Daniel is highly recommended.  He provided all...
# 17  Kevin And Nicky  The Houseboat was truly fabulous. A great loca...
# 20         Mathilde  The location is perfect and the boat is perfec...
# 21    Josh & Winnie  We had a lovely time in Derks houseboat in Ams...
#
#                                      comments_cleaned reviewer_name_cleaned  \
# 4   my wife and i recently stopped in amsterdam fo...                 brian
# 9   daniel is highly recommended he provided all n...               sherwin
# 17  the houseboat was truly fabulous a great locat...       kevin and nicky
# 20  the location is perfect and the boat is perfec...              mathilde
# 21  we had a lovely time in derks houseboat in ams...           josh winnie
#
#                                       comments_tokens reviewer_name_tokens
# 4   [wife, recently, stop, amsterdam, day, honeymo...              [brian]
# 9   [daniel, highly, recommend, provided, necessit...            [sherwin]
# 17  [houseboat, truly, fabulous, great, location, ...       [kevin, nicky]
# 20  [location, perfect, boat, perfect, derk, reall...           [mathilde]
# 21  [lovely, time, derks, houseboat, amsterdam, gr...       [josh, winnie]

# %%
# Function to perform sentiment analysis
def sentiment_analysis(clean_df):
    def getSubjectivity(text):
        return TextBlob(text).sentiment.subjectivity

    def getPolarity(text):
        return TextBlob(text).sentiment.polarity

    def getAnalysis(score):
        if score < 0:
            return 'Negative'
        elif score == 0:
            return 'Neutral'
        else:
            return 'Positive'

    # Create three new columns 'TextBlob_Subjectivity', 'TextBlob_Polarity' and 'TextBlob_Analysis'
    clean_df['TextBlob_Subjectivity'] = clean_df['comments_cleaned'].apply(getSubjectivity)
    clean_df['TextBlob_Polarity'] = clean_df['comments_cleaned'].apply(getPolarity)
    clean_df['TextBlob_Analysis'] = clean_df['TextBlob_Polarity'].apply(getAnalysis)

    return clean_df

# %%
# Apply sentiment analysis using TextBlob and preview the results
clean_df = sentiment_analysis(clean_df)
clean_df
# Out:
#           reviewer_name                                           comments  \
# 4                 Brian  My wife and I recently stopped in Amsterdam fo...
# 9               Sherwin  Daniel is highly recommended.  He provided all...
# 17      Kevin And Nicky  The Houseboat was truly fabulous. A great loca...
# 20             Mathilde  The location is perfect and the boat is perfec...
# 21        Josh & Winnie  We had a lovely time in Derks houseboat in Ams...
# ...                 ...                                                ...
# 342819           Sophie  The staff were really nice and attentive. The ...
# 342837            Terry  This hotel was fantastic. Quality staff, rooms...
# 342853            Barry                    Great hotel, fantastic location
# 342870       Christofer                                Great place to stay
# 342876             Octa  Clean and modern rooms, friendly staff, easy a...
#
#                                          comments_cleaned  \
# 4       my wife and i recently stopped in amsterdam fo...
# 9       daniel is highly recommended he provided all n...
# 17      the houseboat was truly fabulous a great locat...
# 20      the location is perfect and the boat is perfec...
# 21      we had a lovely time in derks houseboat in ams...
# ...                                                   ...
# 342819  the staff were really nice and attentive the s...
# 342837  this hotel was fantastic quality staff rooms a...
# 342853                     great hotel fantastic location
# 342870                                great place to stay
# 342876  clean and modern rooms friendly staff easy acc...
#
#        reviewer_name_cleaned  \
# 4                      brian
# 9                    sherwin
# 17           kevin and nicky
# 20                  mathilde
# 21               josh winnie
# ...                      ...
# 342819                sophie
# 342837                 terry
# 342853                 barry
# 342870            christofer
# 342876                  octa
#
#                                           comments_tokens  \
# 4       [wife, recently, stop, amsterdam, day, honeymo...
# 9       [daniel, highly, recommend, provided, necessit...
# 17      [houseboat, truly, fabulous, great, location, ...
# 20      [location, perfect, boat, perfect, derk, reall...
# 21      [lovely, time, derks, houseboat, amsterdam, gr...
# ...                                                   ...
# 342819  [staff, really, nice, attentive, studio, perfe...
# 342837  [hotel, fantastic, quality, staff, room, ameni...
# 342853                [great, hotel, fantastic, location]
# 342870                               [great, place, stay]
# 342876  [clean, modern, room, friendly, staff, easy, a...
#
#        reviewer_name_tokens  TextBlob_Subjectivity  TextBlob_Polarity  \
# 4                   [brian]               0.528399           0.172183
# 9                 [sherwin]               0.450000           0.222778
# 17           [kevin, nicky]               0.570880           0.341944
# 20               [mathilde]               0.680000           0.615000
# 21           [josh, winnie]               0.572222           0.386111
# ...                     ...                    ...                ...
# 342819             [sophie]               0.920000           0.673333
# 342837              [terry]               0.691667           0.305556
# 342853              [barry]               0.825000           0.600000
# 342870         [christofer]               0.750000           0.800000
# 342876               [octa]               0.566667           0.329167
#
#        TextBlob_Analysis
# 4               Positive
# 9               Positive
# 17              Positive
# 20              Positive
# 21              Positive
# ...                  ...
# 342819          Positive
# 342837          Positive
# 342853          Positive
# 342870          Positive
# 342876          Positive
#
# [28923 rows x 9 columns]

# %% [markdown]
# ## Visualization ##

# %%
# Count the occurrences of each sentiment
clean_df['TextBlob_Analysis'].value_counts()
# Out:
# TextBlob_Analysis
# Positive    28282
# Neutral       423
# Negative      218
# Name: count, dtype: int64

# %%
# Assign the occurrences of each sentiment into a variable for chart plotting
sentiment_counts = clean_df['TextBlob_Analysis'].value_counts()

# %%
# Plot the sentiments
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Analysis')

plt.show()

# %% [markdown]
# ## Evaluation ##

# %%
# Adjust the index number for the comment's sentiment we wish to evaluate
test = TextBlob(clean_df['comments_cleaned'][20])

# Print the sentiment polarity result
print(test.sentiment.polarity)

# Print the sentiment polarity result
print(test.sentiment.subjectivity)
# Out:
# 0.615
# 0.68
